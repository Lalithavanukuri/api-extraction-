# %%
#API Application programming interface--data pipelines--which carry information from one pointA to pointB..
# It gives info in form of json format
#Air booking case,facebook

# %%
import pandas as pd
import requests

# %%
response=requests.get()

# %%
requests.get('https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=vote_average.desc&without_genres=99,10755&vote_count.gte=200')
# Out:
# <Response [401]>

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1NzlkMDU4Mzk5MjIzMjU0NTkzNjJhOTYyOWUwYWJkMiIsInN1YiI6IjY0YmQ5Njc0YWM2Yzc5MDhkZDFkMjU0MSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Lnm35-g-o_qWZQaxJ8FIX-0ozGkZ6-dhR9FD_BjbBQs"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/tmU7GeKVybMWFButWEGl2M4GeiP.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.","popularity":137.867,"poster_path":"/3bhkrj58Vtu7enYsRolD1fZdja1.jpg","release_date":"1972-03-14","title":"The Godfather","video":false,"vote_average":8.7,"vote_count":18264},{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 137.867,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 18264},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path          genre_ids      id  \
# 0   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg           [18, 80]     238
# 1   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg           [18, 80]     278
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg           [18, 80]     240
# 3   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg    [35, 18, 10749]   19404
# 4   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg    [18, 36, 10752]     424
# 5   False  /mSDsSDwaP3E7dEfUPWy4J0djt4O.jpg    [16, 10751, 14]     129
# 6   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg               [18]     389
# 7   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg    [10749, 16, 18]  372058
# 8   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg       [35, 53, 18]  496243
# 9   False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg   [18, 28, 80, 53]     155
# 10  False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg       [14, 18, 80]     497
# 11  False  /4HodYYKEIsGOdinkGi2Ucz6X9i0.jpg  [28, 12, 16, 878]  569094
# ...

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3  19404  Dilwale Dulhania Le Jayenge
# 4    424             Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     137.867
# 1  Framed in the 1940s for the double murder of h...   1994-09-23      98.023
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      64.681
# 3  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      31.678
# 4  The true story of how businessman Oskar Schind...   1993-12-15      52.242
#
#    vote_average  vote_count
# 0           8.7       18264
# 1           8.7       24166
# 2           8.6       11022
# 3           8.6        4180
# 4           8.6       14284

# %%
df.shape
# Out:
# (20, 7)

# %%
df.to_csv('movies.csv')
